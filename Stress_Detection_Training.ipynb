# %% [markdown]
# <a href="https://colab.research.google.com/github/COSMIC-2318/nurse-stress-detection/blob/master/Stress_Detection_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = "/content/drive/MyDrive/nurse_data.csv"

nurse = pd.read_csv(path, on_bad_lines='skip', engine='python')

# %%
nurse.tail()
# Out:
#              X     Y     Z       EDA     HR   TEMP  id  \
# 11509046 -16.0 -56.0  24.0  3.386070  88.37  33.77  F5
# 11509047  -8.0 -50.0  27.0  3.386070  88.37  33.77  F5
# 11509048 -28.0 -36.0  28.0  3.386070  88.37  33.77  F5
# 11509049 -29.0 -29.0  30.0  3.386070  88.37  33.77  F5
# 11509050 -22.0 -24.0  29.0  3.374543  88.33  33.75  F5
#
#                                datetime  label
# 11509046  2020-07-23 17:28:59.875000064    2.0
# 11509047  2020-07-23 17:28:59.906249984    2.0
# 11509048  2020-07-23 17:28:59.937499904    2.0
# 11509049  2020-07-23 17:28:59.968750080    2.0
# 11509050  2020-07-23 17:29:00.000000000    2.0

# %%
nurse.head()
# Out:
#       X     Y     Z       EDA     HR   TEMP  id  \
# 0 -13.0 -61.0   5.0  6.769995  99.43  31.17  15
# 1 -20.0 -69.0  -3.0  6.769995  99.43  31.17  15
# 2 -31.0 -78.0 -15.0  6.769995  99.43  31.17  15
# 3 -47.0 -65.0 -38.0  6.769995  99.43  31.17  15
# 4 -67.0 -57.0 -53.0  6.769995  99.43  31.17  15
#
#                         datetime  label
# 0  2020-07-08 14:03:00.000000000    2.0
# 1  2020-07-08 14:03:00.031249920    2.0
# 2  2020-07-08 14:03:00.062500096    2.0
# 3  2020-07-08 14:03:00.093750016    2.0
# 4  2020-07-08 14:03:00.124999936    2.0

# %%
nurse.dtypes
# Out:
# X           float64
# Y           float64
# Z           float64
# EDA         float64
# HR          float64
# TEMP        float64
# id           object
# datetime     object
# label       float64
# dtype: object

# %%
for i in nurse.columns:
    print(i,':',"\n",nurse[i].unique(),"\n")
# Out:
# X :
#  [ -13.  -20.  -31.  -47.  -67.   -9.    9.   -6.   -1.  -41.  -52.  -22.
#   -26.  -24.  -15.  -29.    1.   14.   11.   -5.   -8.  -17.  -12.  -27.
#    33.   17.   -3.  -74. -101.  -30.    2.   -2.  -43.  -49.  -34.  -16.
#   -32.  -36.  -40.  -44.  -45.  -48.  -57.  -54.  -46.  -51.  -21.  -23.
#   -33.  -70.  -77.  -68.  -60.  -64.  -65.  -58.  -61.  -75.  -55.  -56.
#   -42.  -50.  -63.  -38.  -62.  -39.  -66.  -76.  -71.  -69.  -53.  -35.
#   -37.  -73.  -96.  -81.  -59.  -91.  -84.  -83.  -99.  -72.  -25.  -10.
#   -11.  -18.  -14.   -7.    0.   -4.  -19.  -28.    3.    4.    6.    5.
#     7.   13.   12.   25.   19. -112.  -87.  -88.    8.   27.   20.  -79.
#  -126. -115.  -90.  -85.  -98.  -78.   10.   15.   22.  -80.  -89.  -86.
#   -82.   16. -103.  -97. -122.  -94. -111.  -93. -116. -109.   18. -100.
#   -92. -102. -108.  -95.   26.   24.   48.   36.   40.   55.   60.   52.
#    21.   31.   30.   32.   37.   41.   53.   29.   39.   45.   54.   47.
#    43.   35.   38.   28.   34.   23.   42.   49.   44.   51.   56.   50.
#    61.   75.   74. -128. -106. -105. -107. -113. -104. -114.   84.   89.
#    62.   46.   57.   70.   65.   59.   63.   76.   58.   68.   77.   95.
#   111.   78.   79.   72.   64.   93. -117. -125. -120. -119. -123. -110.
#  -118. -121. -124.   83.   69. -127.   73.   81.   66.  127.   98.  102.
#   105.   71.   97.   90.   87.   80.   67.   96.  116.  100.  106.  104.
#    85.  107.   99.   82.  112.   88.  117.  101.   92.   94.  108.  123.
#   124.  103.  126.  125.  109.  115.  121.   86.  113.  118.  122.  120.
#   110.   91.  119.  114.]
#
# Y :
#  [ -61.  -69.  -78.  -65.  -57.  -68.  -74.  -63.  -73.  -71.  -67.  -60.
#   -53.  -42.  -52.  -75.  -79.  -77.  -70.  -72.  -64.  -41.  -27.  -23.
#   -76. -102.  -94.  -89.  -81.  -83.  -66.  -45.  -14.    3.    7.    8.
#    -7.  -10.  -18.  -20.  -21.  -13.  -16.  -22.   -2.    2.    6.   13.
#    10.   26.   27.   25.   77.   29.   24.   28.   32.   18.   21.   22.
#    31.    1.   -1.    4.    0.   -3.   -5.    5.    9.   11.   -4.   -6.
#    -8.  -11.  -15.  -12.   15.   17.   14.   -9.   12.   20.   36.  -24.
#   -17.   45.   42.   51.   46.   43.   47.   50.   39.   40.   44.   48.
#    49.   52.   56.   80.   55.   53.   54.   57.   58.   59.   60.   61.
#    62.   63.   64.   30.   23.   16.   19.   38.   33.   41.   34.   35.
#    37.  -19.  -35.  -30.  -32.  -26.   83.  -28.  -34.  -33.  -31.  -29.
#   -43.  -56.  -54.  -50.  -36.  -49.  -47.  -44.  -38.  -51.  -85.  -58.
#   -87.  -48.  -55.  -39.  -86.  -97.  -40.  -37.  -59.  -46.  -82.   65.
#    71.   72.   66.  -80.  -84.  -62.   73.  -25.   68.   70.   76.   67.
#    81.   93.   90.   92.   85.   69.   78.   84.   89.  -93.  -90.   82.
#    97.  -98. -105.  -91.  -88.   75. -104.  -92.   79. -121.  -96.  -99.
#  -103. -101. -106. -109. -118. -128. -111.   74.  -95. -113. -119. -114.
#  -100.  111.   91.  127.  104.   86. -112. -122.   87.   95.   88. -125.
#    98. -108.  110. -117. -115. -124. -120. -123. -107. -110.  121. -116.
#  -126.  107.  100.  109.  106.  103.   94.  117. -127.  118.  116.   96.
#    99.  123.  125.  101.  115.  120.  105.  112.  114.  102.  108.  122.
#   124.  113.  126.  119.]
#
# Z :
#  [   5.   -3.  -15.  -38.  -53.  -32.   -2.   17.  -19.  -37.  -29.  -22.
#    -9.  -14.  -25.  -18.  -34.  -16.  -20.  -10.   -4.   -5.  -12.  -23.
#   -26.  -21.   14.   31.    4.    6.   16.   37.   19.    0.   13.    9.
#    20.   33.   34.   29.   26.   28.   35.   42.   43.   44.   46.   49.
#    53.   50.   40.   39.   41.   59.   63.   55.   45.   21.    8.   -1.
#     1.  -13.  -41.  -43.  -31.  -33.  -39.  -24.   -7.   47.   48.   38.
#    36.   24.   25.   52.   51.   54.   56.   60.   30.   27.   32.   61.
#    -6.   -8.   10.   18.   11.    2.    3.   12.   85.  104.   92.   58.
#    23.   22.   15.   71.    7.  -17.  -27.  -28.  -30.   62.   67.   70.
#    65.   69.   66.   87.   78.   57.  -40.  -44.  -42.  -36.  -11.  -35.
#   -45.  -46.  -47.  -52.  -48.  -51.  -49.  -59.  -54.   72.   68.  -50.
#   -55.  115.   64.   73.   76.   75. -128.   79.   84.   83.   89.   74.
#   -58.  -62.   82.   86.   81.   94.   93.  -56.  -65.  -64.  -61.  -67.
#   -63.   88.  -57.  127.  108.   77.   99.   90.   91.  103.  102.   97.
#    98.   80.  -70.  -73.  -69.  -68.  -74.  -71.  -97. -103.  -89.  -75.
#   -60.  -81.  -82.  -78.  -92.  -79.  -66.  111.   96.  110.  100. -112.
#   -85.  -72. -109. -127. -100. -101.  -77.  -83.  -86.  -94.  -90.  -91.
#  -121. -118. -115. -107. -108. -102.  -76.  -93.  -96.  -98.  -88.  -84.
#   106.  107.  -80.  -95. -110.  -99.  -87.   95.  101.  124.  109.  117.
#   105.  116.  121.  123. -116.  125.  118. -117.  112.  119. -113. -123.
#  -120. -114. -105.  120. -124. -106. -122.  122.  126.  114.  113. -119.
#  -125. -126. -104. -111.]
#
# EDA :
#  [6.769995 6.805877 6.789217 ... 3.195243 3.356613 3.411684]
#
# HR :
#  [ 99.43  99.72 100.   ... 136.15 136.43 133.28]
#
# TEMP :
#  [31.17 31.21 31.35 31.19 31.23 31.27 31.33 31.29 31.31 31.37 31.39 31.41
#  31.43 31.49 31.51 31.47 31.53 31.55 31.57 31.59 31.61 31.63 31.65 31.67
#  31.69 31.71 31.45 31.25 31.81 31.75 31.73 31.77 31.79 31.85 31.87 31.83
#  31.95 31.97 31.99 32.   31.93 31.89 31.91 33.91 33.89 34.03 33.97 34.05
#  34.   33.83 33.84 34.11 33.99 33.95 34.09 34.15 33.87 33.77 33.93 33.68
#  33.79 34.13 34.07 34.16 34.18 34.21 34.39 34.41 34.45 34.31 33.73 33.71
#  34.29 34.23 34.34 34.37 34.49 34.53 34.55 34.47 34.43 34.5  34.27 34.25
#  34.33 34.59 34.61 34.66 34.65 34.57 33.75 33.81 33.57 33.66 33.55 33.27
#  33.25 33.41 33.5  33.59 33.63 33.61 33.47 33.29 33.11 33.33 33.37 33.45
#  33.39 33.53 33.43 33.23 33.34 33.49 33.31 33.18 33.09 32.93 33.07 33.16
#  33.13 33.05 33.03 32.91 32.95 32.97 33.   33.21 32.84 32.99 33.15 32.89
#  32.87 32.66 32.68 32.77 32.57 32.65 32.71 32.47 32.21 32.16 32.15 32.25
#  32.33 32.37 32.34 32.29 32.39 32.31 32.41 32.43 32.45 32.49 32.5  32.55
#  32.63 32.61 32.59 32.73 32.75 32.79 32.81 32.83 32.13 32.05 32.09 32.11
#  32.18 32.23 32.27 32.53 33.65 32.03 32.07 35.5  35.49 35.47 35.37 35.43
#  35.45 35.41 35.39 35.33 35.27 35.21 35.18 35.15 35.13 35.25 35.23 35.16
#  35.11 35.05 35.   34.95 34.87 34.89 34.84 34.91 34.93 34.81 34.83 34.79
#  34.75 34.68 34.63 34.71 34.73 34.77 34.97 34.99 35.03 35.07 35.09 35.29
#  35.31 35.34 30.71 30.79 30.83 30.81 30.77 30.69 30.49 30.53 30.51 30.57
#  30.67 30.73 30.65 30.59 30.47 30.43 30.41 30.45 30.37 30.39 30.63 30.61
#  30.33 30.75 36.49 36.5  36.53 36.47 36.55 36.57 36.59 36.45 36.43 36.41
#  36.39 36.37 36.34 36.33 36.31 36.27 36.29 36.23 36.25 36.21 36.18 36.16
#  36.15 36.09 36.13 36.05 36.03 36.   35.99 35.95 35.97 35.93 35.91 35.89
#  35.87 35.84 35.83 35.79 35.77 35.75 35.73 35.71 35.68 35.66 35.65 35.63
#  35.61 35.59 35.57 35.55 35.53 35.81 36.07 36.11 30.31 30.35 30.29 30.55
#  30.85 30.87 30.89 30.91 30.93 30.95 30.99 30.97 31.01 31.03 31.05 31.07
#  31.09 31.11 31.13 31.15 28.65 28.67 28.63 28.69 28.61 28.71 28.73 28.77
#  28.79 28.81 28.83 28.85 28.89 28.87 28.91 28.93 28.95 28.97 28.99 29.03
#  29.01 29.05 29.07 29.09 29.13 29.15 29.17 29.11 28.75 29.21 29.23 29.27
#  29.25 29.29 29.31 29.33 29.19 29.35 28.59 28.57 28.55 28.53 28.51 28.49
#  28.43 28.35 28.41 28.37 28.39 28.45 28.47 29.37 28.33 28.31 30.27 30.21
#  30.19 30.17 30.15 30.13 30.11 30.09 30.07 30.05 30.03 29.99 29.97 29.93
#  29.91 29.87 29.89 29.85 29.83 29.95 30.01 30.23 30.25 29.81 29.79 29.75
#  29.71 29.67 29.69 29.65 29.63 29.61 29.73 29.77 29.57 29.59 29.55 29.53
#  29.51 29.49 29.47 29.43 29.41 29.45 29.39 27.85 27.81 26.93 28.09 27.25
#  27.17 27.09 27.11 27.13 27.27 27.31 27.41 27.75 27.53 26.91 27.21 27.97
#  27.91 27.69 28.29 28.25 28.27 28.23 28.21 28.19 28.17 28.15 28.13 28.11
#  28.07 28.05 28.03 28.01 27.99 27.95 27.93 27.89 27.87 27.83 27.67 27.65
#  27.63 27.61 27.59 27.57 27.47 27.43 27.49 27.71 27.73 27.77 27.79 27.33
#  27.37 27.39 27.35 27.19 27.23 27.07 26.85 26.79 26.77 26.73 26.75 26.71
#  26.81 26.87 26.83 26.89 26.95 26.97 27.01 26.99 27.03 27.05 27.45 27.55
#  27.51 27.29 26.61 26.67 26.31 25.79 25.65 25.49 26.01 26.27 26.15 26.21
#  26.23 26.45 26.57 26.69 26.53 26.51 26.65 27.15 26.49 26.55 26.63 26.47
#  26.59 26.29 25.97 26.25 26.17 26.19 26.39 25.87 26.33 26.41 26.35 26.43
#  25.93 26.07 26.11 26.37 25.91 25.77 25.59 26.05 26.13 25.99 26.09 26.03
#  25.95 25.69 25.53 25.51 25.39 25.67 25.73 25.71 25.27 25.29 25.57 25.43
#  25.61 25.35 25.37 25.45 25.55 25.63 25.75 25.81 25.83 25.85 25.89 25.41
#  25.05 25.09 25.21 25.11 25.15 24.99 24.85 24.91 25.03 24.89 25.31 24.81
#  25.01 25.25 25.47 25.33 25.17 25.19 24.87 24.97 24.25 24.49 24.65 24.55
#  24.45 24.09 24.17 24.37 24.71 24.83 24.93 24.95 25.13 25.07 25.23]
#
# id :
#  ['15' '5C' '6B' '6D' '7A' '7E' '83' '8B' '94' 'BG' 'CE' 'DF' 'E4' 'EG'
#  'F5']
#
# datetime :
#  ['2020-07-08 14:03:00.000000000' '2020-07-08 14:03:00.031249920'
#  '2020-07-08 14:03:00.062500096' ... '2020-07-23 17:28:59.937499904'
#  '2020-07-23 17:28:59.968750080' '2020-07-23 17:29:00.000000000']
#
# label :
#  [2. 0. 1.]

# %%
nurse.isnull().sum()
# Out:
# X           0
# Y           0
# Z           0
# EDA         0
# HR          0
# TEMP        0
# id          0
# datetime    0
# label       0
# dtype: int64

# %%
sns.boxenplot(y=nurse.EDA,x=nurse.label,palette='rainbow')
plt.show()
# Out:
# /tmp/ipython-input-3871929492.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(y=nurse.EDA,x=nurse.label,palette='rainbow')

# %%
nurse = nurse.drop(columns=['X','Y','Z','id'])
nurse.head()
# Out:
#         EDA     HR   TEMP                       datetime  label
# 0  6.769995  99.43  31.17  2020-07-08 14:03:00.000000000    2.0
# 1  6.769995  99.43  31.17  2020-07-08 14:03:00.031249920    2.0
# 2  6.769995  99.43  31.17  2020-07-08 14:03:00.062500096    2.0
# 3  6.769995  99.43  31.17  2020-07-08 14:03:00.093750016    2.0
# 4  6.769995  99.43  31.17  2020-07-08 14:03:00.124999936    2.0

# %%
nurse['datetime'] = pd.to_datetime(nurse['datetime'], format='mixed')
nurse['shift'] = nurse['datetime'].dt.hour
nurse.head()
# Out:
#         EDA     HR   TEMP                      datetime  label  shift
# 0  6.769995  99.43  31.17 2020-07-08 14:03:00.000000000    2.0     14
# 1  6.769995  99.43  31.17 2020-07-08 14:03:00.031249920    2.0     14
# 2  6.769995  99.43  31.17 2020-07-08 14:03:00.062500096    2.0     14
# 3  6.769995  99.43  31.17 2020-07-08 14:03:00.093750016    2.0     14
# 4  6.769995  99.43  31.17 2020-07-08 14:03:00.124999936    2.0     14

# %%
nurse['shift'] = nurse['shift'].apply(lambda x: 0 if 6 <= x < 18 else 1)
nurse.head()
# Out:
#         EDA     HR   TEMP                      datetime  label  shift
# 0  6.769995  99.43  31.17 2020-07-08 14:03:00.000000000    2.0      0
# 1  6.769995  99.43  31.17 2020-07-08 14:03:00.031249920    2.0      0
# 2  6.769995  99.43  31.17 2020-07-08 14:03:00.062500096    2.0      0
# 3  6.769995  99.43  31.17 2020-07-08 14:03:00.093750016    2.0      0
# 4  6.769995  99.43  31.17 2020-07-08 14:03:00.124999936    2.0      0

# %%
nurse = nurse.drop(columns=['datetime'])

# %%
nurse.head()
# Out:
#         EDA     HR   TEMP  label  shift
# 0  6.769995  99.43  31.17    2.0      0
# 1  6.769995  99.43  31.17    2.0      0
# 2  6.769995  99.43  31.17    2.0      0
# 3  6.769995  99.43  31.17    2.0      0
# 4  6.769995  99.43  31.17    2.0      0

# %%
#sns.pairplot(nurse,hue='label',palette='cool')
#plt.show()

# %%
nurse.describe()
# Out:
#                 EDA            HR          TEMP         label         shift
# count  1.150905e+07  1.150905e+07  1.150905e+07  1.150905e+07  1.150905e+07
# mean   3.502127e+00  8.576090e+01  3.223435e+01  1.554202e+00  3.673351e-01
# std    5.656541e+00  1.419642e+01  2.260516e+00  7.891827e-01  4.820789e-01
# min    0.000000e+00  5.100000e+01  2.409000e+01  0.000000e+00  0.000000e+00
# 25%    2.242060e-01  7.672000e+01  3.019000e+01  1.000000e+00  0.000000e+00
# 50%    1.157407e+00  8.390000e+01  3.257000e+01  2.000000e+00  0.000000e+00
# 75%    4.077436e+00  9.310000e+01  3.425000e+01  2.000000e+00  1.000000e+00
# max    5.976071e+01  1.802300e+02  3.659000e+01  2.000000e+00  1.000000e+00

# %%
label_counts = nurse['label'].value_counts().sort_index()
print("Frequency of each label:")
print(label_counts)
# Out:
# Frequency of each label:
# label
# 0.0    2162246
# 1.0     806222
# 2.0    8540583
# Name: count, dtype: int64

# %%
# Calculate percentages
label_proportions = nurse['label'].value_counts(normalize=True).sort_index() * 100
print("\nPercentage distribution:")
print(label_proportions)
# Out:
# Percentage distribution:
# label
# 0.0    18.787353
# 1.0     7.005113
# 2.0    74.207535
# Name: proportion, dtype: float64

# %%
# Define the target count based on the minority class (Label 1.0)
target_count = 806222

# Perform random undersampling for each group
# We use a random_state for reproducibility
balanced_nurse = nurse.groupby('label').apply(
    lambda x: x.sample(n=target_count, random_state=42)
).reset_index(drop=True)

# Shuffle the final dataset so the labels are not ordered
balanced_nurse = balanced_nurse.sample(frac=1, random_state=42).reset_index(drop=True)

# Verification of the new distribution
print("Balanced Label Distribution:")
print(balanced_nurse['label'].value_counts())
# Out:
# /tmp/ipython-input-4126224766.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   balanced_nurse = nurse.groupby('label').apply(
# Balanced Label Distribution:
# label
# 2.0    806222
# 1.0    806222
# 0.0    806222
# Name: count, dtype: int64

# %%
balanced_nurse.describe()
# Out:
#                 EDA            HR          TEMP         label         shift
# count  2.418666e+06  2.418666e+06  2.418666e+06  2.418666e+06  2.418666e+06
# mean   3.234727e+00  8.618850e+01  3.201236e+01  1.000000e+00  4.453658e-01
# std    5.612559e+00  1.429130e+01  2.310718e+00  8.164967e-01  4.970062e-01
# min    0.000000e+00  5.100000e+01  2.409000e+01  0.000000e+00  0.000000e+00
# 25%    2.383560e-01  7.637000e+01  3.003000e+01  0.000000e+00  0.000000e+00
# 50%    8.140100e-01  8.407000e+01  3.215000e+01  1.000000e+00  0.000000e+00
# 75%    3.619550e+00  9.385000e+01  3.411000e+01  2.000000e+00  1.000000e+00
# max    5.948647e+01  1.802300e+02  3.659000e+01  2.000000e+00  1.000000e+00

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical

# 1. Define Features (EDA, TEMP, HR, SHIFT) and Target
X = balanced_nurse[['EDA', 'TEMP', 'HR', 'shift']]
y = balanced_nurse['label']

# 2. Preprocessing
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
y_encoded = to_categorical(y)  # Converts 0, 1, 2 into [1,0,0], [0,1,0], [0,0,1]

# 3. Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42)

# %%
model = Sequential([
    # Input Layer & First Hidden Layer
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.2),

    # Second Hidden Layer
    Dense(32, activation='relu'),
    Dropout(0.2),

    # Third Hidden Layer
    Dense(16, activation='relu'),

    # Output Layer (3 nodes for labels 0, 1, 2)
    Dense(3, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=1024, validation_split=0.2)
# Out:
# Epoch 1/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.5206 - loss: 0.9615 - val_accuracy: 0.6587 - val_loss: 0.7689
# Epoch 2/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6288 - loss: 0.8079 - val_accuracy: 0.6889 - val_loss: 0.7067
# Epoch 3/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6568 - loss: 0.7575 - val_accuracy: 0.7106 - val_loss: 0.6643
# Epoch 4/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6723 - loss: 0.7284 - val_accuracy: 0.7134 - val_loss: 0.6466
# Epoch 5/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6806 - loss: 0.7113 - val_accuracy: 0.7260 - val_loss: 0.6289
# Epoch 6/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6875 - loss: 0.6973 - val_accuracy: 0.7311 - val_loss: 0.6152
# Epoch 7/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6912 - loss: 0.6885 - val_accuracy: 0.7364 - val_loss: 0.6017
# Epoch 8/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6956 - loss: 0.6800 - val_accuracy: 0.7431 - val_loss: 0.5953
# Epoch 9/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6996 - loss: 0.6731 - val_accuracy: 0.7494 - val_loss: 0.5859
# Epoch 10/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7020 - loss: 0.6676 - val_accuracy: 0.7483 - val_loss: 0.5854
# Epoch 11/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7040 - loss: 0.6623 - val_accuracy: 0.7494 - val_loss: 0.5783
# Epoch 12/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7056 - loss: 0.6602 - val_accuracy: 0.7529 - val_loss: 0.5745
# Epoch 13/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7066 - loss: 0.6571 - val_accuracy: 0.7505 - val_loss: 0.5749
# Epoch 14/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7072 - loss: 0.6556 - val_accuracy: 0.7553 - val_loss: 0.5679
# Epoch 15/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7091 - loss: 0.6516 - val_accuracy: 0.7573 - val_loss: 0.5674
# Epoch 16/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7094 - loss: 0.6500 - val_accuracy: 0.7532 - val_loss: 0.5693
# Epoch 17/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7110 - loss: 0.6477 - val_accuracy: 0.7601 - val_loss: 0.5611
# Epoch 18/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7114 - loss: 0.6461 - val_accuracy: 0.7534 - val_loss: 0.5628
# Epoch 19/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7121 - loss: 0.6445 - val_accuracy: 0.7567 - val_loss: 0.5598
# Epoch 20/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7123 - loss: 0.6429 - val_accuracy: 0.7568 - val_loss: 0.5569
# Epoch 21/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7131 - loss: 0.6410 - val_accuracy: 0.7629 - val_loss: 0.5548
# Epoch 22/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7134 - loss: 0.6407 - val_accuracy: 0.7611 - val_loss: 0.5555
# Epoch 23/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7148 - loss: 0.6386 - val_accuracy: 0.7576 - val_loss: 0.5570
# Epoch 24/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7162 - loss: 0.6367 - val_accuracy: 0.7623 - val_loss: 0.5524
# Epoch 25/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7161 - loss: 0.6358 - val_accuracy: 0.7606 - val_loss: 0.5507
# Epoch 26/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7162 - loss: 0.6353 - val_accuracy: 0.7621 - val_loss: 0.5502
# Epoch 27/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7163 - loss: 0.6336 - val_accuracy: 0.7626 - val_loss: 0.5512
# Epoch 28/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7166 - loss: 0.6337 - val_accuracy: 0.7634 - val_loss: 0.5466
# Epoch 29/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7172 - loss: 0.6334 - val_accuracy: 0.7622 - val_loss: 0.5487
# Epoch 30/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7177 - loss: 0.6319 - val_accuracy: 0.7648 - val_loss: 0.5474
# Epoch 31/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7182 - loss: 0.6299 - val_accuracy: 0.7610 - val_loss: 0.5456
# Epoch 32/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.7191 - loss: 0.6288 - val_accuracy: 0.7690 - val_loss: 0.5429
# Epoch 33/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7199 - loss: 0.6278 - val_accuracy: 0.7630 - val_loss: 0.5461
# Epoch 34/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7190 - loss: 0.6281 - val_accuracy: 0.7666 - val_loss: 0.5420
# Epoch 35/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7206 - loss: 0.6263 - val_accuracy: 0.7704 - val_loss: 0.5393
# Epoch 36/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7206 - loss: 0.6270 - val_accuracy: 0.7662 - val_loss: 0.5415
# Epoch 37/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7202 - loss: 0.6270 - val_accuracy: 0.7673 - val_loss: 0.5415
# Epoch 38/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7210 - loss: 0.6251 - val_accuracy: 0.7652 - val_loss: 0.5411
# Epoch 39/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7212 - loss: 0.6238 - val_accuracy: 0.7658 - val_loss: 0.5403
# Epoch 40/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7219 - loss: 0.6237 - val_accuracy: 0.7699 - val_loss: 0.5414
# Epoch 41/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7217 - loss: 0.6240 - val_accuracy: 0.7614 - val_loss: 0.5421
# Epoch 42/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7219 - loss: 0.6233 - val_accuracy: 0.7661 - val_loss: 0.5369
# Epoch 43/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7224 - loss: 0.6231 - val_accuracy: 0.7679 - val_loss: 0.5345
# Epoch 44/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7218 - loss: 0.6228 - val_accuracy: 0.7702 - val_loss: 0.5379
# Epoch 45/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7223 - loss: 0.6221 - val_accuracy: 0.7689 - val_loss: 0.5367
# Epoch 46/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7223 - loss: 0.6222 - val_accuracy: 0.7645 - val_loss: 0.5397
# Epoch 47/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7231 - loss: 0.6208 - val_accuracy: 0.7701 - val_loss: 0.5373
# Epoch 48/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7236 - loss: 0.6196 - val_accuracy: 0.7705 - val_loss: 0.5329
# Epoch 49/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7240 - loss: 0.6192 - val_accuracy: 0.7686 - val_loss: 0.5345
# Epoch 50/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7225 - loss: 0.6212 - val_accuracy: 0.7708 - val_loss: 0.5332
# Epoch 51/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7239 - loss: 0.6202 - val_accuracy: 0.7709 - val_loss: 0.5342
# Epoch 52/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7242 - loss: 0.6184 - val_accuracy: 0.7684 - val_loss: 0.5342
# Epoch 53/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7236 - loss: 0.6194 - val_accuracy: 0.7700 - val_loss: 0.5335
# Epoch 54/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7250 - loss: 0.6186 - val_accuracy: 0.7705 - val_loss: 0.5345
# Epoch 55/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7251 - loss: 0.6177 - val_accuracy: 0.7660 - val_loss: 0.5428
# Epoch 56/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7250 - loss: 0.6183 - val_accuracy: 0.7698 - val_loss: 0.5360
# Epoch 57/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7239 - loss: 0.6193 - val_accuracy: 0.7683 - val_loss: 0.5312
# Epoch 58/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7249 - loss: 0.6166 - val_accuracy: 0.7704 - val_loss: 0.5325
# Epoch 59/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7263 - loss: 0.6166 - val_accuracy: 0.7712 - val_loss: 0.5309
# Epoch 60/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7257 - loss: 0.6161 - val_accuracy: 0.7709 - val_loss: 0.5293
# Epoch 61/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7249 - loss: 0.6171 - val_accuracy: 0.7671 - val_loss: 0.5378
# Epoch 62/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7253 - loss: 0.6170 - val_accuracy: 0.7703 - val_loss: 0.5325
# Epoch 63/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7256 - loss: 0.6162 - val_accuracy: 0.7691 - val_loss: 0.5323
# Epoch 64/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7261 - loss: 0.6175 - val_accuracy: 0.7670 - val_loss: 0.5354
# Epoch 65/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.7258 - loss: 0.6168 - val_accuracy: 0.7712 - val_loss: 0.5314
# Epoch 66/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7261 - loss: 0.6147 - val_accuracy: 0.7682 - val_loss: 0.5314
# Epoch 67/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7250 - loss: 0.6171 - val_accuracy: 0.7703 - val_loss: 0.5289
# Epoch 68/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7263 - loss: 0.6155 - val_accuracy: 0.7689 - val_loss: 0.5308
# Epoch 69/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7266 - loss: 0.6153 - val_accuracy: 0.7665 - val_loss: 0.5366
# Epoch 70/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7254 - loss: 0.6159 - val_accuracy: 0.7721 - val_loss: 0.5301
# Epoch 71/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7268 - loss: 0.6149 - val_accuracy: 0.7704 - val_loss: 0.5314
# Epoch 72/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7260 - loss: 0.6163 - val_accuracy: 0.7701 - val_loss: 0.5286
# Epoch 73/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7266 - loss: 0.6149 - val_accuracy: 0.7667 - val_loss: 0.5323
# Epoch 74/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.7261 - loss: 0.6153 - val_accuracy: 0.7683 - val_loss: 0.5335
# Epoch 75/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7265 - loss: 0.6151 - val_accuracy: 0.7693 - val_loss: 0.5340
# Epoch 76/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7275 - loss: 0.6138 - val_accuracy: 0.7690 - val_loss: 0.5310
# Epoch 77/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7256 - loss: 0.6162 - val_accuracy: 0.7701 - val_loss: 0.5303
# Epoch 78/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7272 - loss: 0.6136 - val_accuracy: 0.7671 - val_loss: 0.5340
# Epoch 79/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7263 - loss: 0.6144 - val_accuracy: 0.7716 - val_loss: 0.5281
# Epoch 80/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7263 - loss: 0.6149 - val_accuracy: 0.7706 - val_loss: 0.5308
# Epoch 81/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7269 - loss: 0.6136 - val_accuracy: 0.7702 - val_loss: 0.5330
# Epoch 82/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7271 - loss: 0.6146 - val_accuracy: 0.7703 - val_loss: 0.5293
# Epoch 83/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7276 - loss: 0.6136 - val_accuracy: 0.7712 - val_loss: 0.5291
# Epoch 84/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7271 - loss: 0.6139 - val_accuracy: 0.7696 - val_loss: 0.5328
# Epoch 85/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7271 - loss: 0.6143 - val_accuracy: 0.7695 - val_loss: 0.5321
# Epoch 86/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7281 - loss: 0.6129 - val_accuracy: 0.7695 - val_loss: 0.5343
# Epoch 87/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7272 - loss: 0.6133 - val_accuracy: 0.7741 - val_loss: 0.5259
# Epoch 88/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7276 - loss: 0.6137 - val_accuracy: 0.7713 - val_loss: 0.5275
# Epoch 89/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7264 - loss: 0.6142 - val_accuracy: 0.7703 - val_loss: 0.5292
# Epoch 90/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7283 - loss: 0.6120 - val_accuracy: 0.7737 - val_loss: 0.5261
# Epoch 91/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7285 - loss: 0.6131 - val_accuracy: 0.7709 - val_loss: 0.5310
# Epoch 92/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7289 - loss: 0.6116 - val_accuracy: 0.7687 - val_loss: 0.5308
# Epoch 93/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7284 - loss: 0.6122 - val_accuracy: 0.7727 - val_loss: 0.5297
# Epoch 94/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7286 - loss: 0.6124 - val_accuracy: 0.7736 - val_loss: 0.5272
# Epoch 95/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7283 - loss: 0.6124 - val_accuracy: 0.7713 - val_loss: 0.5292
# Epoch 96/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7282 - loss: 0.6126 - val_accuracy: 0.7725 - val_loss: 0.5301
# Epoch 97/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7289 - loss: 0.6116 - val_accuracy: 0.7684 - val_loss: 0.5357
# Epoch 98/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7284 - loss: 0.6115 - val_accuracy: 0.7719 - val_loss: 0.5321
# Epoch 99/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7279 - loss: 0.6129 - val_accuracy: 0.7740 - val_loss: 0.5274
# Epoch 100/100
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7281 - loss: 0.6123 - val_accuracy: 0.7752 - val_loss: 0.5299

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Generate predictions
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)

# Print Detailed Report
print("Validation Report:")
print(classification_report(y_true, y_pred, target_names=['Baseline', 'Stress', 'Amusement/Activity']))
# Out:
# 15117/15117 ━━━━━━━━━━━━━━━━━━━━ 23s 1ms/step
# Validation Report:
#                     precision    recall  f1-score   support
#
#           Baseline       0.82      0.78      0.80    161267
#             Stress       0.73      0.89      0.80    161160
# Amusement/Activity       0.80      0.65      0.72    161307
#
#           accuracy                           0.77    483734
#          macro avg       0.78      0.77      0.77    483734
#       weighted avg       0.78      0.77      0.77    483734

# %%
import joblib

# Save the scaler to a file
joblib.dump(scaler, 'stress_scaler.pkl')

print("Scaler saved successfully.")
# Out:
# Scaler saved successfully.

# %%
# Save the entire model
model.save('stress_detection_model.keras')

print("Deep Learning model saved successfully.")
# Out:
# Deep Learning model saved successfully.

# %%
"""import joblib
from tensorflow.keras.models import load_model
import numpy as np

# 1. Load the assets
loaded_scaler = joblib.load('stress_scaler.pkl')
loaded_model = load_model('stress_detection_model.keras')

# 2. Prepare new data (Example: EDA, TEMP, HR, Shift)
new_data = np.array([[5.2, 31.5, 110, 0]])

# 3. SCALE THE NEW DATA using the LOADED scaler
new_data_scaled = loaded_scaler.transform(new_data)

# 4. Predict
prediction_prob = loaded_model.predict(new_data_scaled)
predicted_label = np.argmax(prediction_prob)

print(f"Predicted Stress Category: {predicted_label}")"""
# Out:
# 'import joblib\nfrom tensorflow.keras.models import load_model\nimport numpy as np\n\n# 1. Load the assets\nloaded_scaler = joblib.load(\'stress_scaler.pkl\')\nloaded_model = load_model(\'stress_detection_model.keras\')\n\n# 2. Prepare new data (Example: EDA, TEMP, HR, Shift)\nnew_data = np.array([[5.2, 31.5, 110, 0]])\n\n# 3. SCALE THE NEW DATA using the LOADED scaler\nnew_data_scaled = loaded_scaler.transform(new_data)\n\n# 4. Predict\nprediction_prob = loaded_model.predict(new_data_scaled)\npredicted_label = np.argmax(prediction_prob)\n\nprint(f"Predicted Stress Category: {predicted_label}")'

# %%
"""model = Sequential([
    Dense(256, activation='relu', input_shape=(X_train.shape[1],)), # Corrected input_shape
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(3, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=200, batch_size=1024, validation_split=0.2)"""
# Out:
# "model = Sequential([\n    Dense(256, activation='relu', input_shape=(X_train.shape[1],)), # Corrected input_shape\n    Dense(128, activation='relu'),\n    Dense(64, activation='relu'),\n    Dense(3, activation='softmax')\n])\n\nmodel.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])\n\n# Train the model\nhistory = model.fit(X_train, y_train, epochs=200, batch_size=1024, validation_split=0.2)"

# %%
import pandas as pd
import numpy as np
import sklearn
import tensorflow as tf
import joblib
import platform

print("--- Environment & Library Versions ---")
print(f"Python:     {platform.python_version()}")
print(f"Pandas:     {pd.__version__}")
print(f"NumPy:      {np.__version__}")
print(f"Scikit-Learn:{sklearn.__version__}")
print(f"TensorFlow: {tf.__version__}")
print(f"Joblib:     {joblib.__version__}")
print("--------------------------------------")
# Out:
# --- Environment & Library Versions ---
# Python:     3.12.12
# Pandas:     2.2.2
# NumPy:      2.0.2
# Scikit-Learn:1.6.1
# TensorFlow: 2.19.0
# Joblib:     1.5.3
# --------------------------------------
